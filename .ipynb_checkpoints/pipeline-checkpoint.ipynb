# %%
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
# import pyspark as ps

# spark = ps.sql.SparkSession.builder \
#         .master("local[4]") \
#         .appName("df lecture") \
#         .getOrCreate()

# sc = spark.sparkContext

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# import boto3

# %%
# s3 = boto3.client("s3")

# %%
# bucket = "chizzy"
# subfolder = "yelp_data"
# file_name = "yelp_data/business.json"
# file_lists = s3.list_objects(Bucket=bucket, Prefix = "{}/".format(subfolder), Delimiter='/')["Contents"][1]["Key"]
# file = s3.get_object(Bucket=bucket, Key="{}".format(file_name))

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
# Access/Initiate Database
db = client["yelp"]
# Access/Initiate Table
tab = db["review"]

# %%
import pickle
with open("../../../downloads/df_rev_bus_user.pickle", "rb") as f:
    df_loaded = pickle.load(f)

# %%
df = df_loaded[df_loaded["state"] == "SC"]

# %%
data = df.to_dict(orient="records")
tab.insert_many(data)

# %%
name = "Showmars Fort Mill-Hwy 521"
state = "SC"

# %%
dd = client.yelp

# %%
list(dd.review.find())[:10]
# Out:
# [{'_id': ObjectId('5b7474fb2041bebfbfed1ad1'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 3.63,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 17,
#   'compliment_cute': 0,
#   'compliment_funny': 17,
#   'compliment_hot': 17,
#   'compliment_list': 0,
#   'compliment_more': 6,
#   'compliment_note': 20,
#   'compliment_photos': 2,
#   'compliment_plain': 12,
#   'compliment_profile': 0,
#   'compliment_writer': 25,
#   'cool': 108,
#   'cool_rev': 0,
#   'date': datetime.datetime(2017, 6, 14, 0, 0),
#   'elite': [2015, 2013, 2011, 2012],
#   'fans': 9,
#   'friends': ['TG6rBirDvjNY_aCCnK_GQw',
#    'tHkwA5dqeyeoPoNN9qvovQ',
#    'jfaz1aQqnkbtzQfQyCE8IA',
#    'LP9j1YqgWPJGw1zY_LRuzg',
#    'CR-ze9lR7fokp0fM8g5lYw',
#    'JjXuiru1_ONzDkYVrHN0aw',
#    'BCQ6Aa6sVz2fIsYDrCbYRA',
#    'G-mWHSm6XVp1oe9PN7NUPg',
#    'DR7KoX4alg12vwIOnKjxbg',
#    'DYt0HZUjMKkYgxBL7xUNSw',
#    'uMVR9islTFEWD9TzDxr2rw',
#    'sdLns7062kz3Ur_b8wgeYw',
#    'Bsbumyr3Of8BauN2URK4bg',
#    '62GNFh5FySkA3MbrQmnqvg',
#    '-rlIN1BFK65MyHWt_HhPJg',
#    'GCjCyKgQC6hk3vRqbA-bAA',
#    'AvC5XQAElcGAAn_Wr5auEg',
#    '5qk2OW5PLcmQ2ryBcn0ZXQ',
#    'yDgBhl1QH-z7UMb6i98SOA',
#    'H7JLpACO44A3xVXnOt1Z_A',
#    'REJJdS_0ViOYqMby49Q0sQ',
#    'S7u-XAuq1xHhMyRo30h_tw',
#    'cM5nBvgS1Lmmto_dCfwY3Q',
#    'aIt8TKiYoPk7MW-5EZqZFA',
#    'QLgFEumhrHq6LgbEOKCzdw',
#    'x-1oCEXf8unHrA_zfr6QXQ',
#    'xJafm7vGSkUI5ocgYkCWkA',
#    'RS5JztShXARj8kDJoDs0-g',
#    '7M-rWYRGPfCDnb7tjl7QGQ',
#    'qlC607Cyp0Mj91vDFvkp3Q',
#    'Tfs_BWBZVgJuk8gc4FIETQ',
#    'aDYNz8cujkDdmbiOh95ANA',
#    'Vq73g5hdDBdxdBOfkEYqyw',
#    'i8rLR6sf6ofeZ7YzsOg_kA',
#    'GGTF7hnQi6D5W77_qiKlqg',
#    '3IIx8iT8B-z8woy-DfmPtw',
#    '6WdxUn95dt_z-63FDvTh1g',
#    'hWDybu_KvYLSdEFzGrniTw',
#    'uT-yzDkY79szXYNWk7zDzQ',
#    'I6DOULDVlRpIHuhV3rQpTg',
#    'q2tFhT8pC4ml8sI8QTEadA',
#    'nNPUS5hkWLHcprRK2mnQbw',
#    'N_DyK1LaBsxfZ1kmHP1Ssw',
#    'zsZBYWYEmLLs81_f-HHM8w',
#    'b99tjloA0KavKBW-BNe2lA',
#    'VbfaQcyRqSZ0rGvhgg-3Fw'],
#   'funny': 175,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': 'dLmYfTfOv8Z6PPURHr29mw',
#   'stars': 3.5,
#   'stars_rev': 5,
#   'state': 'SC',
#   'text': "You know what? For what it is, this Showmars is top notch. A five star review doesn't = a five star restaurant experience of course, but if you want casual fast food in a clean environment, at a reasonable price and with polite staff, Showmars is the place to get it. \n\nThe menu is interesting, a combination of casual Greek food, burgers and seafood. I've tried several of the Greek menu items, as well as the fish sandwich and the Calabash shrimp plate. Everything I've had has been top notch, but if I have to ding them for anything - and it's not enough to take off a star - they don't carry malt vinegar in the restaurant which seems a shame because that's all it would take for them to have a killer fish and chips meal!\n\nMy favorites are the crinkle cut fries, the hush puppies, their cole slaw, tzatziki and Greek salad. Every order I get fills at least one or two of those cravings.\n\nTable runners are spot-on to refill drinks or get you anything you need. The only thing is I feel guilty about not leaving a cash tip, since there's no room to tip on a card at the register, and I go cashless almost 100% of the time. One of these days I'll pack a wad of singles into the console of my car so I can leave the table runners a buck or so for their fast and friendly service. As it is, I often sit close enough to the drink machine to grab my own refills and I self-buss my own mess. It's the former waitress in me coming out.\n\nGood for singles, couples, families, lunch or dinner. Not a romantic joint, but doesn't try to pretend it is. You can even phone in an order and pick it up at their drive-thru window. Not much more you can ask for. Well, maybe a little malt vinegar...",
#   'useful': 548,
#   'useful_rev': 0,
#   'user_id': 'IZXnSMdOkVdFH-mw6zQBbA',
#   'user_name': 'Cat',
#   'user_rev_count': 113,
#   'yelping_since': '2008-09-22'},
#  {'_id': ObjectId('5b7474fb2041bebfbfed1ad2'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 2.75,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 0,
#   'compliment_cute': 0,
#   'compliment_funny': 0,
#   'compliment_hot': 0,
#   'compliment_list': 0,
#   'compliment_more': 2,
#   'compliment_note': 0,
#   'compliment_photos': 0,
#   'compliment_plain': 0,
#   'compliment_profile': 0,
#   'compliment_writer': 0,
#   'cool': 0,
#   'cool_rev': 0,
#   'date': datetime.datetime(2014, 6, 16, 0, 0),
#   'elite': [],
#   'fans': 0,
#   'friends': ['36V5ou8KWqGEHn2vIHOY0g'],
#   'funny': 0,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': '4ogboSCXqYFVYvBEPbA9OA',
#   'stars': 3.5,
#   'stars_rev': 4,
#   'state': 'SC',
#   'text': 'First time going and was pleasantly surprised. Food was great, place was clean and service was quick.',
#   'useful': 2,
#   'useful_rev': 0,
#   'user_id': 'I1cu-KXx0vUSlhhjBwjxFA',
#   'user_name': 'N',
#   'user_rev_count': 8,
#   'yelping_since': '2014-02-01'},
#  {'_id': ObjectId('5b7474fb2041bebfbfed1ad3'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 3.8,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 0,
#   'compliment_cute': 0,
#   'compliment_funny': 0,
#   'compliment_hot': 0,
#   'compliment_list': 0,
#   'compliment_more': 0,
#   'compliment_note': 0,
#   'compliment_photos': 0,
#   'compliment_plain': 0,
#   'compliment_profile': 0,
#   'compliment_writer': 0,
#   'cool': 0,
#   'cool_rev': 0,
#   'date': datetime.datetime(2017, 2, 17, 0, 0),
#   'elite': [],
#   'fans': 0,
#   'friends': ['802fYLZVtrEnHAhbd8KJMA',
#    'v01_qD50LC52W4E_z0iO7w',
#    'bfrfVZp4gkF0uSgPqx7RYQ',
#    'WxmJwHayCnxKY76nRjXZvQ',
#    'XOD-r0fLGqhHlRvI3cK70A',
#    'Uz7--JBAEXQsQH4vKuKX8A',
#    'KPixKymgwe_8_JTQZaK1ww',
#    'CQLvN2_ClBrLxNJ0imutAg',
#    'zGmdZl6XUN69hun1F6GaTg',
#    '0zNF_ETA_NgiyLZUie3ZlQ',
#    'bzC78qzdSbHugGLGVNBEOw',
#    'dB2ZkVi9J37sUL0f2_S-gg',
#    'heJ0F99__D-sSHBU55qD-A',
#    'aCZihx8XXMNzzxIZFfzx_A',
#    '6XEvZJ35boNKCtidk1TrRg',
#    'c0IhEJDReFdV-qAIJRMj5Q',
#    'UOm1RdnSk96CmRcl-i8h3g',
#    'uY72QsJysgI-g4uY5PFzXQ',
#    'FyLypyqOQdPBJ86NGYMy_A',
#    'wiSsui3RUnZ1pJZwziunJQ',
#    'SPQsBpFP5qlZebjZExJfUQ',
#    'O-FYN0tJdSTGwFhai3EpGA',
#    'y7SQiYjwvLChaXfJFzf0Lg',
#    'jos7Ou69tzdP6GRXabUdlg',
#    'DfvIk6HYMI0OWWogRDyUag',
#    'HIOdEy5zfnIYmfU3R0X0xg',
#    'RsYWgIY0wPxTWmY3wq5lVQ',
#    'DdhkfTqbO4oYRCdw49OOkA',
#    '-JEojAfLfWHjFPcm9KWi3Q',
#    'rjrNeNRLXUZ02fln7zMM-A',
#    'D5_6oW9aSKevBdOGwSvzBg',
#    '58qIiDYTcmYrbiyLT7MHxg',
#    'WT_6mD_AKXFzwzBdnJGLAA',
#    '7aZhRYJdjYnwn5KCgDhxGQ',
#    'eU_w1R1tOkXTn_s2_GFefw',
#    'd1AWHks2fPdurSF6rsdJQw',
#    'idrQgYgC3y_TJABAoGRaHw',
#    'STM1rHCK3WaubTKK9Mb5cw',
#    'ZZN_5B03m0Uzvvq6nqW_xg',
#    '4V8dD9Kx6zc4omz_87Hx2Q',
#    'ivBFVM3_tyi14rwTmrRPrA',
#    'AQOev3-aExFgO6Fq4qSlPA',
#    'vKwDZe56mZZ8kQo93o95kA',
#    'xAWv1_jcos8hP54k8AWMKw',
#    'm_TRsm34aD8PiZAxaU0uDA',
#    'KC-VsNac1YGwvm7pYWabxw',
#    '-_P-YCuhigrMk1WxfGx94g',
#    'PaflsWnmW5-MbE6vzLO89w',
#    '18SpcDT_YhODrqUJEs8hwg',
#    'lzWCWbx3yo3USNkkmGnZ-g',
#    'amO8MJUli0-tIIuGgiVEfg',
#    'Mm0RvpMBlHKacTd3EihmpA',
#    'xY9V131hwL5X_qW4AxOZmA',
#    '4XjfnvWM4Edokw1qI_oIcA',
#    'H2lVRRShnbij_CzAH4qvxw',
#    '-oJg1AFPU-FIWqSuOr-dNw',
#    'ibVBOh4deyLkzB5h7ND53Q',
#    'yrJnO3gj6mah8JSN0nZkhA',
#    'gkjX6Ge2lEfqIZlrqk_ftA',
#    'Sj0i8V31Wh-gtbE3ftrbog',
#    'Fhn8TPI59f4K5e5sDJonQQ',
#    'UFy5G0t5-hPlYUOtpFW-nA',
#    'BvWq_ax4LYvW6Zc6ZJFO6A',
#    'YCoriYuVCzc9St19UEsjog',
#    '0sl4I8R7znWXp_K4A0nZ_w',
#    'v4uuFgAa8U0LZSV42uyMwg',
#    '8td8oivg6nNjrckRXsaWTA',
#    '5QR6fEKPQBbu9oI4cGp4IQ',
#    'PJvLVAJebqfQqrWKkr62Tg',
#    'jadBrM0aYQdZwoMuBklhqg',
#    '17dc5NtQoQXn8GS00LDmkQ',
#    'OBMzkvreDTDoiJmoQNQYjg',
#    'bgdB3g48vG_evEXNe5RMsA',
#    '2ejveqmJqsgKGlTFGZXXUA',
#    '6-UTO08v_1HUqZLiAyrFwg',
#    'PkDD-4pA8FoJPV0acJ11bQ',
#    'kaj7pY4VHX_c63zKApXhtw',
#    'BQmdIhWXL6EDWMaXaeXsfg',
#    'Ee4cxyGq-CuOpUzzW_i9pw',
#    'fog71CxnHTc7JtMDLmGTJA',
#    '_eBP8SKQTegmEzjvHU5eQA',
#    'R2OHmLdhzVJb0T9n4P3jzA',
#    's2sQws0WIcyq0pmypbHCxw',
#    'Yxi9OMBONRWdexDKVCfpAQ'],
#   'funny': 0,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': 'JuPlibj9l9ftcW8phOXq2w',
#   'stars': 3.5,
#   'stars_rev': 4,
#   'state': 'SC',
#   'text': "I come here for lunch because they are really quick with their service and bringing your food out. All the servers are very nice. \n\nI usually go with the pita burgers or the salad. But there's great variety and always a daily lunch special. \n\nHighly recommended. Also they have updated their decor which is a pleasant touch.",
#   'useful': 1,
#   'useful_rev': 0,
#   'user_id': 'dMBnipSx49OpdYFalvK1BQ',
#   'user_name': 'Ryan',
#   'user_rev_count': 5,
#   'yelping_since': '2015-01-13'},
#  {'_id': ObjectId('5b7474fb2041bebfbfed1ad4'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 3.9699999999999998,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 0,
#   'compliment_cute': 0,
#   'compliment_funny': 0,
#   'compliment_hot': 0,
#   'compliment_list': 0,
#   'compliment_more': 0,
#   'compliment_note': 2,
#   'compliment_photos': 0,
#   'compliment_plain': 4,
#   'compliment_profile': 0,
#   'compliment_writer': 0,
#   'cool': 6,
#   'cool_rev': 0,
#   'date': datetime.datetime(2016, 8, 23, 0, 0),
#   'elite': [2016, 2017],
#   'fans': 1,
#   'friends': ['L-fR2rT0GPja8E8aIjdE4A',
#    'dit8T1eV8sjIjnX9e5Ppdg',
#    'goD9U0ythNHNOEZi24RGZA',
#    'SJ4JJuxSnx6kB1Q8s4uVdg',
#    'y8CMJUMpv3O_gfkrtI3WIw',
#    'jpy1Bu-Do5vOqFOdIjPXQA',
#    'l6j28Kbhen5j7_6tCnO7RA',
#    '2fOwbc0zn6_LHMF1zR72fA',
#    'GGTF7hnQi6D5W77_qiKlqg',
#    'xAn9rQHLv_-i3NEhpg0meA',
#    '2HyKSbLBJRQ7yAScxjFm5w',
#    'fvbGDgNKCM1KcMDmM3PEbA',
#    'ZV0SKtodNE4Y3RRcIbHERg',
#    'LaEvjenEi0bkpebe1n6bww',
#    'RlsyX5YbaDrkpHyO1GY4Fg',
#    'XTKmGj9fvuSsI4PvpaATqg',
#    '9_So86otKXp--dkKU9MZ1w',
#    'Ui_LRqa3GXckUsxNmgZlNg',
#    'BwLuBmKTh0J_vUxGJpCWFw',
#    'zKRuXXpgLHSXHjG_POW2Nw',
#    'o0jh4d1HN-UaFaBb6lZxgg',
#    '_6Aj8y8RvQ24Ha0J3hXRDg',
#    'u-NbxbNdh7GZGnwxXUitYg',
#    'wZcF2z_uraqbr5u6C-mIOA',
#    '2mfzHeHrGVebIx6rfCVT8w',
#    'R76z0ltNXHAEJvjSaUAUCA',
#    'b8ZWLH8leZE8gD5emSvg4A',
#    'nuGTjs2_SFmQMn0KVh8RIg',
#    'rpcCryH42lc2jopKnYs9iw',
#    'hcnMTj5fRbFeLIjOg-gIzA',
#    'gWWFPzqrOcFqF2U0-NJbDQ',
#    'F5I2g5AJBVl0UGt7dF7wqQ',
#    'zxBcqIIzldNzwL4cbWNhyQ',
#    'EfgFIptbkmDWf7yLwr4yeA',
#    '7GIcGERUfVvOx_TNYomGcA'],
#   'funny': 5,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': 'KH6MA3Y0FVM_5iiA5_ooNA',
#   'stars': 3.5,
#   'stars_rev': 5,
#   'state': 'SC',
#   'text': "Last time I was there I got a fish platter that was absolutely delightful. The fish was perfectly cooked not to try not to uncooked it was just perfect in the middle. Their coleslaw is some of the only coleslaw I will eat and there are other food that I've ever tasted has always been top notch. I've had a few different fish sandwiches and have never been disappointed.\n The service always is friendly and polite and the restaurant is kept very very clean.",
#   'useful': 28,
#   'useful_rev': 0,
#   'user_id': '-6559fkJ6rCWIZDbqVUomA',
#   'user_name': 'Judith',
#   'user_rev_count': 86,
#   'yelping_since': '2016-05-15'},
#  {'_id': ObjectId('5b7474fb2041bebfbfed1ad5'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 4.6,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 0,
#   'compliment_cute': 0,
#   'compliment_funny': 0,
#   'compliment_hot': 0,
#   'compliment_list': 0,
#   'compliment_more': 0,
#   'compliment_note': 0,
#   'compliment_photos': 0,
#   'compliment_plain': 0,
#   'compliment_profile': 0,
#   'compliment_writer': 0,
#   'cool': 0,
#   'cool_rev': 0,
#   'date': datetime.datetime(2017, 9, 7, 0, 0),
#   'elite': [],
#   'fans': 0,
#   'friends': [],
#   'funny': 0,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': '9huSfoaoVIw7uZI3R-6ZJg',
#   'stars': 3.5,
#   'stars_rev': 5,
#   'state': 'SC',
#   'text': "Hamburgers are very good and taste like homemade.  However, I love a good fish fry!  This is the place to go if you do too.  The flounder platter is excellent!  Flakey fish in a delicious batter.  Not at all greasy.  French fries are amazing!  Their coleslaw is also very good.  Free drink refills.  Family atmosphere and reasonable prices that won't break the bank.  You can also call ahead for take out at their drive through window.",
#   'useful': 2,
#   'useful_rev': 0,
#   'user_id': 'fAxE5bDdi3UnB-nwDiEoVA',
#   'user_name': 'Judy',
#   'user_rev_count': 13,
#   'yelping_since': '2016-02-04'},
#  {'_id': ObjectId('5b7474fb2041bebfbfed1ad6'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 4.0,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 0,
#   'compliment_cute': 0,
#   'compliment_funny': 0,
#   'compliment_hot': 0,
#   'compliment_list': 0,
#   'compliment_more': 0,
#   'compliment_note': 0,
#   'compliment_photos': 0,
#   'compliment_plain': 0,
#   'compliment_profile': 0,
#   'compliment_writer': 0,
#   'cool': 0,
#   'cool_rev': 0,
#   'date': datetime.datetime(2016, 4, 24, 0, 0),
#   'elite': [],
#   'fans': 0,
#   'friends': [],
#   'funny': 0,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': '-sRotW388hqEDZthdD68jg',
#   'stars': 3.5,
#   'stars_rev': 5,
#   'state': 'SC',
#   'text': 'Very friendly staff!! Came in 10 minutes before closing and went up to get a box, the manager told us not to rush and to take our time and eat. Very kind and yummy food too!!',
#   'useful': 0,
#   'useful_rev': 0,
#   'user_id': '-xE_7COR8mX9Jo_AT4x_yQ',
#   'user_name': 'Madison',
#   'user_rev_count': 4,
#   'yelping_since': '2016-01-09'},
#  {'_id': ObjectId('5b7474fb2041bebfbfed1ad7'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 2.87,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 0,
#   'compliment_cute': 0,
#   'compliment_funny': 0,
#   'compliment_hot': 1,
#   'compliment_list': 0,
#   'compliment_more': 0,
#   'compliment_note': 0,
#   'compliment_photos': 0,
#   'compliment_plain': 0,
#   'compliment_profile': 0,
#   'compliment_writer': 0,
#   'cool': 4,
#   'cool_rev': 1,
#   'date': datetime.datetime(2013, 9, 6, 0, 0),
#   'elite': [],
#   'fans': 0,
#   'friends': ['updcPk6zUz_-7GZ2xob_EA', 'xIfifPltgEm6DCZw12YEHw'],
#   'funny': 0,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': '5iNAF-RjoLoNM69UPQWbCQ',
#   'stars': 3.5,
#   'stars_rev': 4,
#   'state': 'SC',
#   'text': 'Short and simple. \nGood food, fast service and tasty.  Just a tad bit salty for my taste.   Overall, I will be a local going more often.',
#   'useful': 2,
#   'useful_rev': 0,
#   'user_id': 'lzbOiFu190qEhX9tQLFW6A',
#   'user_name': 'Knows',
#   'user_rev_count': 23,
#   'yelping_since': '2009-02-18'},
#  {'_id': ObjectId('5b7474fb2041bebfbfed1ad8'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 3.23,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 0,
#   'compliment_cute': 0,
#   'compliment_funny': 0,
#   'compliment_hot': 0,
#   'compliment_list': 0,
#   'compliment_more': 0,
#   'compliment_note': 1,
#   'compliment_photos': 0,
#   'compliment_plain': 0,
#   'compliment_profile': 0,
#   'compliment_writer': 0,
#   'cool': 0,
#   'cool_rev': 0,
#   'date': datetime.datetime(2016, 6, 29, 0, 0),
#   'elite': [],
#   'fans': 0,
#   'friends': ['zWo3anxTkXSrBjJdkCHULA',
#    'auSiwTlaUXMwOo0uHYuc1w',
#    'gIQ-F75s__LsMSS1R6Iv3A',
#    'jKgQYvEt90f5h7yhjJNqkg'],
#   'funny': 0,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': 'PURDDq_UG_qj6M7j0ZB_Ag',
#   'stars': 3.5,
#   'stars_rev': 2,
#   'state': 'SC',
#   'text': 'Place is never clean.\nThe schwarma or gyro is much better at their South Park location or go to THe Arboretum to the Greek place there.',
#   'useful': 0,
#   'useful_rev': 0,
#   'user_id': 'oxdOFmY0YWW4gFq5jJr-hg',
#   'user_name': 'Bob',
#   'user_rev_count': 49,
#   'yelping_since': '2015-05-24'},
#  {'_id': ObjectId('5b7474fb2041bebfbfed1ad9'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 3.67,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 0,
#   'compliment_cute': 0,
#   'compliment_funny': 0,
#   'compliment_hot': 0,
#   'compliment_list': 0,
#   'compliment_more': 0,
#   'compliment_note': 0,
#   'compliment_photos': 0,
#   'compliment_plain': 0,
#   'compliment_profile': 0,
#   'compliment_writer': 0,
#   'cool': 0,
#   'cool_rev': 0,
#   'date': datetime.datetime(2015, 11, 19, 0, 0),
#   'elite': [],
#   'fans': 0,
#   'friends': [],
#   'funny': 0,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': 'NXpQy_1Aksy0-NbBw8LlJQ',
#   'stars': 3.5,
#   'stars_rev': 5,
#   'state': 'SC',
#   'text': 'Delicious! Fast, fun and friendly staff! This is a good place to spot in to for a quick, fresh and hot meal.',
#   'useful': 0,
#   'useful_rev': 1,
#   'user_id': 'b9kWibYlcuH-87mVMcuf3Q',
#   'user_name': 'Tommy',
#   'user_rev_count': 2,
#   'yelping_since': '2015-11-18'},
#  {'_id': ObjectId('5b7474fb2041bebfbfed1ada'),
#   'address': '9783 Charlotte Hwy',
#   'attributes': {'Alcohol': 'none',
#    'Ambience': {'casual': True,
#     'classy': False,
#     'divey': False,
#     'hipster': False,
#     'intimate': False,
#     'romantic': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False},
#    'BikeParking': True,
#    'BusinessAcceptsCreditCards': True,
#    'BusinessParking': {'garage': False,
#     'lot': True,
#     'street': False,
#     'valet': False,
#     'validated': False},
#    'Caters': True,
#    'GoodForKids': True,
#    'GoodForMeal': {'breakfast': False,
#     'brunch': False,
#     'dessert': False,
#     'dinner': False,
#     'latenight': False,
#     'lunch': True},
#    'HasTV': True,
#    'NoiseLevel': 'average',
#    'OutdoorSeating': True,
#    'RestaurantsAttire': 'casual',
#    'RestaurantsDelivery': False,
#    'RestaurantsGoodForGroups': True,
#    'RestaurantsPriceRange2': 1,
#    'RestaurantsReservations': False,
#    'RestaurantsTableService': False,
#    'RestaurantsTakeOut': True,
#    'WiFi': 'no'},
#   'average_stars': 3.61,
#   'bus_name': 'Showmars Fort Mill-Hwy 521',
#   'bus_rev_count': 30,
#   'business_id': '2DODGcOKKhegTzscdwWRig',
#   'categories': ['Greek', 'American (New)', 'Restaurants'],
#   'city': 'Fort Mill',
#   'compliment_cool': 0,
#   'compliment_cute': 0,
#   'compliment_funny': 0,
#   'compliment_hot': 0,
#   'compliment_list': 0,
#   'compliment_more': 0,
#   'compliment_note': 0,
#   'compliment_photos': 0,
#   'compliment_plain': 0,
#   'compliment_profile': 0,
#   'compliment_writer': 0,
#   'cool': 0,
#   'cool_rev': 0,
#   'date': datetime.datetime(2015, 5, 1, 0, 0),
#   'elite': [],
#   'fans': 0,
#   'friends': ['wSByVbwME4MzgkJaFyfvNg',
#    'XB_zwMj2I5JzzCNn8U1j2w',
#    'l5GG76vqaA0kCScL5HAu6g'],
#   'funny': 0,
#   'funny_rev': 0,
#   'hours': {'Friday': '10:30-21:30',
#    'Monday': '10:30-21:00',
#    'Saturday': '10:30-21:30',
#    'Sunday': '11:00-15:00',
#    'Thursday': '10:30-21:00',
#    'Tuesday': '10:30-21:00',
#    'Wednesday': '10:30-21:00'},
#   'is_open': 1,
#   'latitude': 35.0029435694,
#   'longitude': -80.8561164206,
#   'neighborhood': '',
#   'postal_code': '29707',
#   'review_id': '1znha0Z9Ce7C6zcAKJUi5A',
#   'stars': 3.5,
#   'stars_rev': 1,
#   'state': 'SC',
#   'text': 'Stopped in late Thursday.  Had a double pita burger and fries.  Wife had chicken pita and greek salad.  Great friendly staff.  My food was good, however my wife ended up getting sick in the middle of the night from hers.  Thats why the low rating.',
#   'useful': 0,
#   'useful_rev': 0,
#   'user_id': 'Ivvtn65VRwpd7J-4S5Qc7A',
#   'user_name': 'Paul',
#   'user_rev_count': 28,
#   'yelping_since': '2013-08-02'}]

# %%
dat1 = pd.DataFrame(list(dd.review.find({"bus_name": name, "state":state}).limit(5)))

# %%
dat1.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dat = pd.DataFrame(list(db.review.find({"bus_name": name, "state":state}).limit(5)))

# %%
dat.head()
# Out:
#                         _id             address  \
# 0  5b7474fb2041bebfbfed1ad1  9783 Charlotte Hwy
# 1  5b7474fb2041bebfbfed1ad2  9783 Charlotte Hwy
# 2  5b7474fb2041bebfbfed1ad3  9783 Charlotte Hwy
# 3  5b7474fb2041bebfbfed1ad4  9783 Charlotte Hwy
# 4  5b7474fb2041bebfbfed1ad5  9783 Charlotte Hwy
#
#                                           attributes  average_stars  \
# 0  {'RestaurantsTableService': False, 'GoodForMea...           3.63
# 1  {'RestaurantsTableService': False, 'GoodForMea...           2.75
# 2  {'RestaurantsTableService': False, 'GoodForMea...           3.80
# 3  {'RestaurantsTableService': False, 'GoodForMea...           3.97
# 4  {'RestaurantsTableService': False, 'GoodForMea...           4.60
#
#                      bus_name  bus_rev_count             business_id  \
# 0  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
# 1  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
# 2  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
# 3  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
# 4  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
#
#                              categories       city  compliment_cool  \
# 0  [Greek, American (New), Restaurants]  Fort Mill               17
# 1  [Greek, American (New), Restaurants]  Fort Mill                0
# 2  [Greek, American (New), Restaurants]  Fort Mill                0
# 3  [Greek, American (New), Restaurants]  Fort Mill                0
# 4  [Greek, American (New), Restaurants]  Fort Mill                0
#
#        ...        stars  stars_rev  state  \
# 0      ...          3.5          5     SC
# 1      ...          3.5          4     SC
# 2      ...          3.5          4     SC
# 3      ...          3.5          5     SC
# 4      ...          3.5          5     SC
#
#                                                 text  useful  useful_rev  \
# 0  You know what? For what it is, this Showmars i...     548           0
# 1  First time going and was pleasantly surprised....       2           0
# 2  I come here for lunch because they are really ...       1           0
# 3  Last time I was there I got a fish platter tha...      28           0
# 4  Hamburgers are very good and taste like homema...       2           0
#
#                   user_id  user_name  user_rev_count  yelping_since
# 0  IZXnSMdOkVdFH-mw6zQBbA        Cat             113     2008-09-22
# 1  I1cu-KXx0vUSlhhjBwjxFA          N               8     2014-02-01
# 2  dMBnipSx49OpdYFalvK1BQ       Ryan               5     2015-01-13
# 3  -6559fkJ6rCWIZDbqVUomA     Judith              86     2016-05-15
# 4  fAxE5bDdi3UnB-nwDiEoVA       Judy              13     2016-02-04
#
# [5 rows x 45 columns]

# %%
df_loaded[["bus_name", "text", "stars_rev", "state"]][df_loaded["state"] == "SC"].iloc[20:70,:]
# Out:
#                           bus_name  \
# 597654  Showmars Fort Mill-Hwy 521
# 597655  Showmars Fort Mill-Hwy 521
# 597656  Showmars Fort Mill-Hwy 521
# 597657  Showmars Fort Mill-Hwy 521
# 597658  Showmars Fort Mill-Hwy 521
# 597659  Showmars Fort Mill-Hwy 521
# 597660  Showmars Fort Mill-Hwy 521
# 597661  Showmars Fort Mill-Hwy 521
# 597662  Showmars Fort Mill-Hwy 521
# 597663  Showmars Fort Mill-Hwy 521
# 598105       Liu Lius Asian Bistro
# 598106       Liu Lius Asian Bistro
# 598107       Liu Lius Asian Bistro
# 598108       Liu Lius Asian Bistro
# 598109       Liu Lius Asian Bistro
# 598110       Liu Lius Asian Bistro
# 599150                Golden China
# 599151                Golden China
# 599152                Golden China
# 599153                Golden China
# 599154                Golden China
# 599155                Golden China
# 599156                Golden China
# 599157                Golden China
# 599158                Golden China
# 599159                Golden China
# 599160                Golden China
# 599161                Golden China
# 599162                Golden China
# 599163                Golden China
# 599164                Golden China
# 599165                Golden China
# 599166                Golden China
# 599167                Golden China
# 599168                Golden China
# 599169                Golden China
# 599170                Golden China
# 599171                Golden China
# 599172                Golden China
# 599173                Golden China
# 599174                Golden China
# 599175                Golden China
# 599176                Golden China
# 599177                Golden China
# 599178                Golden China
# 599179                Golden China
# 599180                Golden China
# 599181                Golden China
# 599182                Golden China
# 599183                Golden China
#
#                                                      text  stars_rev state
# 597654  It's a typical showmars which is a good thing....          5    SC
# 597655  Excellent food, and service is truly the best ...          5    SC
# 597656  Our family of 3 ate at this store on a Mon. ni...          1    SC
# 597657  Had never heard of Showmars until moving here ...          3    SC
# 597658  Yummy! The onion rings were insanely delicious...          4    SC
# 597659  Great food! The service was great, and it was ...          5    SC
# 597660  Consistent quality.  That's it!  We can come h...          4    SC
# 597661  The food at Showars is always really good so I...          4    SC
# 597662  We love this Showmars! The food is always serv...          5    SC
# 597663  We decided to go to Showmar's for fish tonight...          4    SC
# 598105  My husband and I tried Liu Liu's in Baxter Vil...          1    SC
# 598106  This is very good asian food.  NOT THE BEST, b...          4    SC
# 598107  A nice spot for Asian cuisine inside of Baxter...          3    SC
# 598108  Had lunch here with a friend. Service and food...          4    SC
# 598109  I paid $12.04 for a Coke and lunch combination...          3    SC
# 598110  Great location and great food\nLove to go here...          4    SC
# 599150  Tried Golden China yesterday based on the revi...          3    SC
# 599151  Delicious food. The flavors are amazing. Menti...          5    SC
# 599152  Really decent hot and sour soup and fried rice...          3    SC
# 599153  My go-to Chinese takeout in NYC (North York Co...          5    SC
# 599154  WOW!! My family and I are from Florida, and we...          5    SC
# 599155  I love this place! This is my go to for take-o...          5    SC
# 599156  I've eaten here several times and I've never b...          5    SC
# 599157  Coming from NJ I finally found the best Chines...          5    SC
# 599158  We have been searching and searching to get Ch...          5    SC
# 599159  We've had a really hard time finding a GOOD Ch...          4    SC
# 599160  I have been going to this specific Golden Chin...          5    SC
# 599161  Not bad take out.  Prices are fair. Food is no...          5    SC
# 599162  Golden China was fine. Nothing was wrong with ...          3    SC
# 599163  This is our go-to Chinese takeout in Regent Pa...          5    SC
# 599164  Food is real good. They cook their wings when ...          3    SC
# 599165  Noticed this almost new restaurant around the ...          4    SC
# 599166  Portions are huge, everything comes hot and fr...          3    SC
# 599167  Very good, not amazing or anything, but defini...          4    SC
# 599168  I grew up in a community in NY that had many f...          5    SC
# 599169  What a pleasant find. The food was good, not s...          4    SC
# 599170  Yummm!!! Have been coming here for a long time...          5    SC
# 599171  Great food! Whether dine in or take out. Very ...          5    SC
# 599172  Stopped by based on yelp reviews.  Great value...          5    SC
# 599173  We wanted to try a new Chinese place and decid...          4    SC
# 599174  Food is delicious and prices are great. Don't ...          5    SC
# 599175  This is my go-to Chinese take out place. It's ...          5    SC
# 599176  Golden China is great! They always get my orde...          4    SC
# 599177  This is the best Chinese food in SC! They cook...          5    SC
# 599178  I just went for the 900th time today (not real...          5    SC
# 599179  I love this place. The fried rice and crab ran...          5    SC
# 599180  Food is okay. The woman at the counter is your...          1    SC
# 599181  Great prices, super fast service!  Steamed dum...          5    SC
# 599182  i have ate here several times. the food is goo...          4    SC
# 599183  Was definitely pleased with our first order an...          4    SC

# %%
import util

# %%
    with open("../../../downloads/models.pickle", "rb") as f:
        models = pickle.load(f)

# %%
lst, name, size, Recall, Precision, Accuracy, lst_neg, lst_pos = util.display(models, df_loaded, 4, 5, state="NV", bus_name="The Garden Grill")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-f1d77c9a299e> in <module>()
# ----> 1 lst, name, size, Recall, Precision, Accuracy, lst_neg, lst_pos = util.display(models, df_loaded, 4, 5, state="NV", bus_name="The Garden Grill")
#
# ValueError: not enough values to unpack (expected 8, got 7)

# %%
name
# Out:
# 'Restaurant Name: The Garden Grill'

# %%
size
# Out:
# 'Size of corpus: 21'

# %%
Recall
# Out:
# 'Recall: 0.6%'

# %%
Precision
# Out:
# 'Precision: 0.5%'

# %%
Accuracy
# Out:
# 'Accuracy: 57.89%'

# %%
lst_neg
# Out:
# [('took', array(['slow'],
#         dtype='<U13')), ('given', array(['reason'],
#         dtype='<U13')), ('cooked', array(['decent'],
#         dtype='<U13')), ('great', array(['overall'],
#         dtype='<U13')), ('fish', array(['ok'],
#         dtype='<U13'))]

# %%
lst_pos
# Out:
# [('fish', array(['best'],
#         dtype='<U12')), ('greeted', array(['awesome'],
#         dtype='<U12')), ('customer', array(['awesome'],
#         dtype='<U12')), ('friggin', array(['best'],
#         dtype='<U12')), ('staff', array(['amazing'],
#         dtype='<U12')), ('item', array(['favorite'],
#         dtype='<U12')), ('taco', array(['amazing'],
#         dtype='<U12')), ('little', array(['awesome'],
#         dtype='<U12')), ("i'm", array(['wow'],
#         dtype='<U12'))]

# %%
type(lst_pos)
# Out:
# list

# %%
with open("data.pickle", "rb") as f:
    data = pickle.load(f)

# %%
data.tail()
# Out:
#                         _id             address  \
# 0  5b7474fb2041bebfbfed1ad1  9783 Charlotte Hwy
# 1  5b7474fb2041bebfbfed1ad2  9783 Charlotte Hwy
# 2  5b7474fb2041bebfbfed1ad3  9783 Charlotte Hwy
# 3  5b7474fb2041bebfbfed1ad4  9783 Charlotte Hwy
# 4  5b7474fb2041bebfbfed1ad5  9783 Charlotte Hwy
#
#                                           attributes  average_stars  \
# 0  {'RestaurantsTableService': False, 'GoodForMea...           3.63
# 1  {'RestaurantsTableService': False, 'GoodForMea...           2.75
# 2  {'RestaurantsTableService': False, 'GoodForMea...           3.80
# 3  {'RestaurantsTableService': False, 'GoodForMea...           3.97
# 4  {'RestaurantsTableService': False, 'GoodForMea...           4.60
#
#                      bus_name  bus_rev_count             business_id  \
# 0  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
# 1  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
# 2  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
# 3  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
# 4  Showmars Fort Mill-Hwy 521             30  2DODGcOKKhegTzscdwWRig
#
#                              categories       city  compliment_cool  \
# 0  [Greek, American (New), Restaurants]  Fort Mill               17
# 1  [Greek, American (New), Restaurants]  Fort Mill                0
# 2  [Greek, American (New), Restaurants]  Fort Mill                0
# 3  [Greek, American (New), Restaurants]  Fort Mill                0
# 4  [Greek, American (New), Restaurants]  Fort Mill                0
#
#        ...        stars  stars_rev  state  \
# 0      ...          3.5          5     SC
# 1      ...          3.5          4     SC
# 2      ...          3.5          4     SC
# 3      ...          3.5          5     SC
# 4      ...          3.5          5     SC
#
#                                                 text  useful  useful_rev  \
# 0  You know what? For what it is, this Showmars i...     548           0
# 1  First time going and was pleasantly surprised....       2           0
# 2  I come here for lunch because they are really ...       1           0
# 3  Last time I was there I got a fish platter tha...      28           0
# 4  Hamburgers are very good and taste like homema...       2           0
#
#                   user_id  user_name  user_rev_count  yelping_since
# 0  IZXnSMdOkVdFH-mw6zQBbA        Cat             113     2008-09-22
# 1  I1cu-KXx0vUSlhhjBwjxFA          N               8     2014-02-01
# 2  dMBnipSx49OpdYFalvK1BQ       Ryan               5     2015-01-13
# 3  -6559fkJ6rCWIZDbqVUomA     Judith              86     2016-05-15
# 4  fAxE5bDdi3UnB-nwDiEoVA       Judy              13     2016-02-04
#
# [5 rows x 45 columns]
